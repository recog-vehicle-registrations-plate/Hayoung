# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
import math
# plt.style.use('dark_background')

# %%
img_ori = cv2.imread('./chr_images_results/extracted_rotated_0401475566590.jpg')


height, width, channel = img_ori.shape

plt.figure(figsize=(12, 10))
plt.imshow(img_ori, cmap='gray')
print(img_ori.shape)
# Out:
# (28, 99, 3)
